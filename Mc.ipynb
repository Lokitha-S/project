# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokitha-S/project/blob/main/Mc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('final.csv')
df.head(4)
# Out:
#    ID  Age  Cycle_Length  Period_Duration  Ovulation_Day  Luteal_Phase_Length  \
# 0   1   24            30                7             10                   10
# 1   2   37            25                4             10                   14
# 2   3   32            30                5             19                   13
# 3   4   28            25                5             18                   11
#
#    Physical_Activity_Level  Stress_Level  Diet_Type  Sleep_Hours  Mood_Swings  \
# 0                        1             1          2          4.3            1
# 1                        1             0          1          8.1            1
# 2                        2             1          1          6.8            0
# 3                        0             2          2          7.5            0
#
#    Cravings  Pain_Level
# 0         0           0
# 1         0           8
# 2         1           8
# 3         0           7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       500 non-null    int64
#  1   Age                      500 non-null    int64
#  2   Cycle_Length             500 non-null    int64
#  3   Period_Duration          500 non-null    int64
#  4   Ovulation_Day            500 non-null    int64
#  5   Luteal_Phase_Length      500 non-null    int64
#  6   Physical_Activity_Level  500 non-null    int64
#  7   Stress_Level             500 non-null    int64
#  8   Diet_Type                500 non-null    int64
#  9   Sleep_Hours              500 non-null    float64
#  10  Mood_Swings              500 non-null    int64
#  11  Cravings                 500 non-null    int64
#  12  Pain_Level               500 non-null    int64
# dtypes: float64(1), int64(12)
# memory usage: 50.9 KB

# %%
df.isnull().sum()
# Out:
# ID                         0
# Age                        0
# Cycle_Length               0
# Period_Duration            0
# Ovulation_Day              0
# Luteal_Phase_Length        0
# Physical_Activity_Level    0
# Stress_Level               0
# Diet_Type                  0
# Sleep_Hours                0
# Mood_Swings                0
# Cravings                   0
# Pain_Level                 0
# dtype: int64

# %%
df.describe().T
# Out:
#                          count      mean         std   min     25%    50%  \
# ID                       500.0  250.5000  144.481833   1.0  125.75  250.5
# Age                      500.0   30.9280    8.147612  18.0   24.00   31.0
# Cycle_Length             500.0   27.3920    4.115849  21.0   24.00   27.0
# Period_Duration          500.0    4.9580    1.421364   3.0    4.00    5.0
# Ovulation_Day            500.0   14.5040    2.931753  10.0   12.00   15.0
# Luteal_Phase_Length      500.0   12.5220    1.713297  10.0   11.00   13.0
# Physical_Activity_Level  500.0    0.9460    0.805221   0.0    0.00    1.0
# Stress_Level             500.0    1.0000    0.835102   0.0    0.00    1.0
# Diet_Type                500.0    1.4720    1.127723   0.0    0.00    2.0
# Sleep_Hours              500.0    7.0718    1.713504   4.0    5.60    7.2
# Mood_Swings              500.0    0.5220    0.500016   0.0    0.00    1.0
# Cravings                 500.0    0.4880    0.500357   0.0    0.00    0.0
# ...

# %%
data='Cycle_Length'

# %%
df.hist(data,bins=20,color='green',edgecolor='black',figsize=(2, 2))
plt.xlabel('Age')
plt.ylabel('Cycle_Length')
plt.title('Age v/s Cycle_length')
plt.show()

# %%
plt.bar(df['Stress_Level'], df['Pain_Level'])
plt.xlabel('Stress_Level')
plt.ylabel('Pain_Level')
plt.show()
