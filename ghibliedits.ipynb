# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokitha-S/project/blob/main/ghibliedits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries



# Load the Ghibli-style Stable Diffusion model
 # Use GPU for faster results

# Upload an image
from google.colab import files
uploaded = files.upload()
input_image_path = list(uploaded.keys())[0]  # Get the uploaded image filename

# Open the uploaded image
image = Image.open(input_image_path).convert("RGB")

# Define the prompt for Ghibli style
prompt = "Studio Ghibli style anime background, soft colors, dreamy atmosphere, fantasy"

# Generate the Ghibli-style image
output_image = pipe(prompt=prompt, image=image, strength=0.7).images[0]

# Save and display the output
output_path = "ghibli_style_output.jpg"
output_image.save(output_path)

# Show the generated image
output_image.show()

# Provide a download link
from google.colab import files
files.download(output_path)

# %%
# !pip install diffusers transformers torch pillow accelerate safetensors
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 868.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from diffusers import StableDiffusionImg2ImgPipeline
import torch
from PIL import Image
import requests
from io import BytesIO

# %%
model_id = "nitrosocke/Ghibli-Diffusion"
pipe = StableDiffusionImg2ImgPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-59dadb5a8c77> in <cell line: 0>()
#       1 model_id = "nitrosocke/Ghibli-Diffusion"
#       2 pipe = StableDiffusionImg2ImgPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
# ----> 3 pipe.to("cuda")
#
# /usr/local/lib/python3.11/dist-packages/diffusers/pipelines/pipeline_utils.py in to(self, *args, **kwargs)
#     459                 module.to(device=device)
#     460             elif not is_loaded_in_4bit_bnb and not is_loaded_in_8bit_bnb:
# --> 461                 module.to(device, dtype)
#     462
#     463             if (
#
# /usr/local/lib/python3.11/dist-packages/diffusers/models/modeling_utils.py in to(self, *args, **kwargs)
# ...

# %%
from google.colab import files
uploaded = files.upload()
input_image_path = list(uploaded.keys())[0]

# %%
from huggingface_hub import login
login()
